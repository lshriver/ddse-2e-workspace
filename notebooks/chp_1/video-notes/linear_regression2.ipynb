# %% [markdown]
# # 🔥 Linear Regression 2
# Source: https://www.youtube.com/watch?v=88_wgLgx0_k&list=PLMrJAkhIeNNSVjnsviglFoY2nXildDCcv&index=20

# %% [markdown]
# $$A\bold{x}=\bold{b}$$
# $$\bold{\tilde{x}}=V\Sigma^{-1}U^Tb$$
#
# Description of data:
#
# - There are 13 different experiments, each with a mix of 4 possible ingredients for making cement (corresponds with a 13 x 4 data matrix -- 13 rows for each experiment and 4 columns for each ingredient).
# - Each entry in the column vector, $\mathbb{b}$ would correspond with a result from an experiment.
#
# - 🥅 Use your data to predict the outcome of untested conditions $\implies$ here, we will do this using muliple regression.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams.update({'font.size': 18})

# Load dataset
A = np.loadtxt('/workspaces/steve-brunton-book/data/hald_ingredients.csv', delimiter=',')
b = np.loadtxt('/workspaces/steve-brunton-book/data/hald_heat.csv', delimiter=',')

# Solve Ax=b using SVD
U, S, VT = np.linalg.svd(A, full_matrices=0)
x = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b 

plt.plot(b, color='k', linewidth=2, label='Heat Data')  # True relation
plt.plot(A@x, '-o', color='r', linewidth=1.5, markersize=6, label='Regression line')
plt.title('Portland Cement Heat Data')
plt.xlabel('Experiment Index')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# # ⚠️ WARNING -- Beware of overfitting!
# DON'T do the following:
# 1. Use all your data to train a model
# 2. Then say your model predicts the data
# 3. This isn't valid!
#
# # 🔰 Training Data vs. Testing Data
# A lot of machine learing is based on the idea of splitting your data up into training data and testing data.
